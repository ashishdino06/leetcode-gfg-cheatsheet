# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishdino06/leetcode-gfg-code/blob/py-gfg/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Coding

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %%
arr=[1, 2, 3, 4, 5]
for i in range(0,len(arr)-2,2):
  arr[i],arr[i+1]=arr[i+1],arr[i]
print(arr)
# Out:
# [2, 1, 4, 3, 5]
