# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishdino06/leetcode-gfg-cheatsheet/blob/py-scripts/py_leet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#unique email addresses
emails = ["test.email+alex@leetcode.com","test.e.mail+bob.cathy@leetcode.com","testemail+david@lee.tcode.com"]
domains=[email.split('@')[1] for email in emails]
local=[email.split('@')[0] for email in emails]

for i in range(len(local)):
  local[i] = local[i].replace('.','').partition('+')[0]


result=[u+'@'+d for u,d in zip(local,domains)]
print(local)
print(result)
print(len(set(result)))
# print(domains)
# Out:
# ['testemail', 'testemail', 'testemail']
# ['testemail@leetcode.com', 'testemail@leetcode.com', 'testemail@lee.tcode.com']
# 2

# %%
#regex appraoch
import re
def numUniqueEmails(emails):
    expression, emails_set = r'([a-z0-9.]+)\+?.*@(\S+)', set()

    for email in emails:
        matches = re.findall(expression, email)
        print(matches)
        email = re.sub(r'\.', '', matches[0][0]) + '@' + matches[0][1]
        print(email)
        emails_set.add(email)
    print(len(emails_set))
emails = ["test.email+alex@leetcode.com","test.e.mail+bob.cathy@leetcode.com","testemail+david@lee.tcode.com"]

numUniqueEmails(emails)
# Out:
# [('test.email', 'leetcode.com')]
# testemail@leetcode.com
# [('test.e.mail', 'leetcode.com')]
# testemail@leetcode.com
# [('testemail', 'lee.tcode.com')]
# testemail@lee.tcode.com
# 2

# %%
#duplicatezeros
arr = [1,0,2,3,0,4,5,0]
print(arr)
i =0
n = len(arr)-1

while i <=n:
  if arr[i]==0:
    for j in range(n,i,-1):
      arr[j]=arr[j-1]
    i+=2
  else:
    i+=1
print(arr)
# Out:
# [1, 0, 2, 3, 0, 4, 5, 0]
# [1, 0, 0, 2, 3, 0, 0, 4]

# %%
from collections import Counter
nums = [20,20,10,30,30,30]
d =  Counter(nums)
ans = -1
print(d)
countOfCount = Counter([value for value in d.values()])

print(countOfCount)
for k,v in countOfCount.items():
    if v==1:
      ke= k
      ans = next((k for k, v in d.items() if v == ke), -1)
      print(ans)
      break
else:
  print(ans)
# Out:
# Counter({30: 3, 20: 2, 10: 1})
# Counter({2: 1, 1: 1, 3: 1})
# 20
